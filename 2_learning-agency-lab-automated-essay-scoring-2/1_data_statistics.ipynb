# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df.score.value_counts()
# Out:
# score
# 3    6280
# 2    4723
# 4    3926
# 1    1252
# 5     970
# 6     156
# Name: count, dtype: int64
